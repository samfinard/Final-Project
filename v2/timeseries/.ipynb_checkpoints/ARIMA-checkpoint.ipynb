# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('master.csv', index_col='date', parse_dates=True, date_format='%m/%d/%y')
df.dropna(subset=['close'],inplace=True)

# %%
df['close'].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.tsa.stattools import adfuller

def ad_test(dataset):
    dftest = adfuller(dataset, autolag = 'AIC')
    print("1. ADF : ", dftest[0])
    print("2. P-Value : ", dftest[1])
    print("3. Num of Lags : ", dftest[2])
    print("4. Num of Observations Used for ADF Regression and Critical Values Calculation : ", dftest[3])
    print("5. Critical Values : ")
    for key, val in dftest[4].items():
        print("\t", key, ": ", val)

# %%
ad_test(df['close'])
# Out:
# 1. ADF :  0.6939720867921543
# 2. P-Value :  0.9897168014012145
# 3. Num of Lags :  11
# 4. Num of Observations Used for ADF Regression and Critical Values Calculation :  240
# 5. Critical Values :
# 	 1% :  -3.4578942529658563
# 	 5% :  -2.8736593200231484
# 	 10% :  -2.573228767361111

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(df['close'],trace=True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1412.824, Time=0.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1421.142, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1420.730, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1420.992, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1422.823, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1423.716, Time=0.10 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1423.872, Time=0.09 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1425.006, Time=0.16 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1415.645, Time=0.27 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1422.198, Time=0.04 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1417.101, Time=0.13 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1423.454, Time=0.15 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1416.367, Time=0.38 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 2.305 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  252
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                -700.412
# Date:                Sun, 15 Oct 2023   AIC                           1412.824
# Time:                        18:53:03   BIC                           1433.977
# Sample:                             0   HQIC                          1421.337
#                                 - 252
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.1673      0.421      2.775      0.006       0.343       1.992
# ar.L1          0.2740      0.051      5.418      0.000       0.175       0.373
# ar.L2         -0.8123      0.040    -20.279      0.000      -0.891      -0.734
# ma.L1         -0.3360      0.028    -11.869      0.000      -0.392      -0.281
# ma.L2          0.9757      0.031     31.805      0.000       0.916       1.036
# sigma2        15.0841      0.657     22.948      0.000      13.796      16.372
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.45   Jarque-Bera (JB):               640.66
# Prob(Q):                              0.50   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.13   Skew:                            -0.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
train = df.iloc[:-30]
test = df.iloc[-30:]

# %%
model = ARIMA(train['close'], order = (2,1,2))
model = model.fit()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model = ARIMA(train['close'], order = (2,1,2))
#       2 model = model.fit()
#       3 model.summary()
#
# File /opt/homebrew/lib/python3.11/site-packages/statsmodels/tsa/arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/statsmodels/tsa/arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.
